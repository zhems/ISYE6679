        1.141305e-03,  6.828760e-04, -1.703930e-04, -8.502650e-05,
        6.975730e-04,  1.014407e-03,  7.955230e-04,  4.478230e-04,
       -1.507849e-03,  8.027360e-04, -5.352500e-04,  1.167422e-03,
        3.231140e-04,  9.592640e-04,  5.951890e-04, -1.043914e-03,
        1.570140e-04,  8.887260e-04, -4.963710e-04,  5.251310e-04,
       -1.624790e-04,  6.095960e-04,  1.085851e-03,  3.988350e-04,
       -1.908930e-05,  1.631620e-03, -3.281830e-04,  2.740420e-04,
       -1.909430e-04,  6.197990e-04, -1.033919e-03, -1.298810e-04,
        1.321023e-03,  5.356330e-04,  7.286150e-04, -2.599210e-04,
       -8.004070e-05,  6.251850e-05, -1.357289e-03, -6.350600e-04,
       -1.887564e-03, -1.597462e-03,  4.115390e-04,  3.478000e-04,
       -1.507849e-03,  2.838580e-04, -6.389210e-04,  4.367780e-04,
        4.699060e-04])
indices = [(np.array([ 7, 25, 33, 34, 36, 37, 38, 48, 51]),),
 (np.array([ 0,  1,  2,  3,  4,  5,  8, 12, 39, 42, 43, 44, 45, 46]),),
 (np.array([18, 19, 22, 26, 27, 30, 31, 35, 41, 47, 49]),),
 (np.array([ 6,  9, 10, 11, 16, 21, 23, 24, 28, 29, 32, 40, 50, 52]),),
 (np.array([13, 14, 15, 17, 20]),)]
type_tuple = [('Conglo', 0), ('FMCG', 1), ('Fin', 2), ('Tech', 3), ('Software', 4)]

# %%
def readcov():
    a = np.array(pd.read_clipboard(header=None))
    for row in range(len(a)-1):
        for col in range(row+1,len(a)):
            a[row][col]=a[col][row]
    return a
def readmeans():
    return np.array(pd.read_clipboard(header=None))[0]

# %%
C = readcov()

# %%
R = readmeans()

# %%
C.shape
# Out:
# (53, 53)

# %%
R.shape
# Out:
# (53,)

# %%
N = 53 # number of countries
prop_country = 0.4
prop_industry = 0.3
expected_returns = 0.0008
N_max = 6
N_country, N_industry = 3, 2

# %%
# Portfolio selection to minimize variance
psp = Model('Portfolio')
X = {}
for i in range(len(R)):
    X[i] = psp.addVar(ub=1.0,name='Stock'+str(i))

a = []
for i in range(len(R)):
    for j in range(len(R)):
        a.append((i,j))

psp.setObjective(quicksum(C[i,j]*X[i]*X[j] for i,j in a))

Constr = {}

Constr['budget'] = psp.addConstr(quicksum(X[i] for i in X.keys()),GRB.EQUAL,1,name = 'budget')
Constr['returns'] = psp.addConstr(quicksum(X[i]*R[i] for i in X.keys()),'>=',expected_returns, name = 'returns')

# ufl.setParam('TimeLimit', 900)
# ufl.setParam('DualReductions',0)

psp.modelSense = GRB.MINIMIZE
psp.update()

psp.optimize()
print('Runtime:',psp.Runtime)
psp.update()
# Out:
# Optimize a model with 2 rows, 53 columns and 106 nonzeros
# Model has 1431 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [7e-06, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-08, 5e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [8e-04, 1e+00]
# Presolve time: 0.01s
# Presolved: 2 rows, 53 columns, 106 nonzeros
# Presolved model has 1431 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 50
#  AA' NZ     : 1.326e+03
#  Factor NZ  : 1.378e+03
#  Factor Ops : 4.823e+04 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.33818982e+05 -2.33818982e+05  2.56e+04 5.35e-07  2.55e+05     0s
#    1   1.20437137e+05 -1.20447331e+05  4.16e+03 8.69e-08  4.32e+04     0s
#    2   1.20909788e+03 -1.22465832e+03  1.04e+02 2.17e-09  1.13e+03     0s
# ...

# %%
# Portfolio selection with country restriction
psp = Model('Portfolio')
X = {}
for i in range(len(R)):
    X[i] = psp.addVar(ub=1.0,name='Stock'+str(i))

a = []
for i in range(len(R)):
    for j in range(len(R)):
        a.append((i,j))
        
#indices
us, hk, uk, end = 0, 26, 38, len(X)

psp.setObjective(quicksum(C[i,j]*X[i]*X[j] for i,j in a))

Constr = {}

Constr['budget'] = psp.addConstr(quicksum(X[i] for i in X.keys()),GRB.EQUAL,1,name = 'budget')
Constr['returns'] = psp.addConstr(quicksum(X[i]*R[i] for i in X.keys()),'>=',expected_returns, name = 'returns')

Constr['us'] = psp.addConstr(quicksum(X[i] for i in range(hk)),'<=',prop_country,name = 'us')
Constr['hk'] = psp.addConstr(quicksum(X[i] for i in range(hk,uk)),'<=',prop_country,name = 'hk')
Constr['uk'] = psp.addConstr(quicksum(X[i] for i in range(uk,end)),'<=',prop_country,name = 'uk')

# ufl.setParam('TimeLimit', 900)
# ufl.setParam('DualReductions',0)

psp.modelSense = GRB.MINIMIZE
psp.update()

psp.optimize()
print('Runtime:',psp.Runtime)
psp.update()
# Out:
# Optimize a model with 5 rows, 53 columns and 159 nonzeros
# Model has 1431 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [7e-06, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-08, 5e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [8e-04, 1e+00]
# Presolve time: 0.01s
# Presolved: 5 rows, 53 columns, 159 nonzeros
# Presolved model has 1431 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 50
#  AA' NZ     : 1.426e+03
#  Factor NZ  : 1.504e+03
#  Factor Ops : 5.432e+04 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.33817829e+05 -2.33817829e+05  1.50e+04 1.24e-04  2.69e+05     0s
#    1   2.78041573e+04 -2.81537838e+04  2.74e+03 2.27e-05  5.02e+04     0s
#    2   1.54495334e+02 -5.85397139e+02  4.51e+01 3.75e-07  8.52e+02     0s
# ...

# %%
# Portfolio selection with country restriction
psp = Model('Portfolio')
X = {}
for i in range(len(R)):
    X[i] = psp.addVar(ub=1.0,name='Stock'+str(i))

a = []
for i in range(len(R)):
    for j in range(len(R)):
        a.append((i,j))
        
#indices
us, hk, uk, end = 0, 26, 38, len(X)

psp.setObjective(quicksum(C[i,j]*X[i]*X[j] for i,j in a))

Constr = {}

Constr['budget'] = psp.addConstr(quicksum(X[i] for i in X.keys()),GRB.EQUAL,1,name = 'budget')
Constr['returns'] = psp.addConstr(quicksum(X[i]*R[i] for i in X.keys()),'>=',expected_returns, name = 'returns')

Constr['us'] = psp.addConstr(quicksum(X[i] for i in range(hk)),'<=',prop_country,name = 'us')
Constr['hk'] = psp.addConstr(quicksum(X[i] for i in range(hk,uk)),'<=',prop_country,name = 'hk')
Constr['uk'] = psp.addConstr(quicksum(X[i] for i in range(uk,end)),'<=',prop_country,name = 'uk')

for row in type_tuple:
    Constr[row[0]] = psp.addConstr(quicksum(X[i] for i in indices[row[1]][0]),'<=',prop_industry,name=row[0])

# ufl.setParam('TimeLimit', 900)
# ufl.setParam('DualReductions',0)

psp.modelSense = GRB.MINIMIZE
psp.update()

psp.optimize()
print('Runtime:',psp.Runtime)
psp.update()
# Out:
# Optimize a model with 10 rows, 53 columns and 212 nonzeros
# Model has 1431 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [7e-06, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-08, 5e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [8e-04, 1e+00]
# Presolve time: 0.01s
# Presolved: 10 rows, 53 columns, 212 nonzeros
# Presolved model has 1431 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  Free vars  : 50
#  AA' NZ     : 1.668e+03
#  Factor NZ  : 1.793e+03
#  Factor Ops : 7.074e+04 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.33811118e+05 -2.33811118e+05  1.50e+04 4.47e-04  2.91e+05     0s
#    1   1.68523376e+04 -1.74822159e+04  2.58e+03 7.85e-05  5.18e+04     0s
#    2   5.30412091e+01 -8.38520426e+02  4.29e+01 1.31e-06  8.92e+02     0s
# ...

# %%
# Portfolio selection with country restriction, industry restriction and max no. of assets
psp = Model('Portfolio')
X = {}
Y = {}
for i in range(len(R)):
    Y[i] = psp.addVar(vtype=GRB.BINARY,name='Stockinside'+str(i))
    X[i] = psp.addVar(ub=1.0,name='Stock'+str(i))

a = []
for i in range(len(R)):
    for j in range(len(R)):
        a.append((i,j))
        
#indices
us, hk, uk, end = 0, 26, 38, len(X)

psp.setObjective(quicksum(C[i,j]*X[i]*X[j] for i,j in a))

Constr = {}

Constr['budget'] = psp.addConstr(quicksum(X[i] for i in X.keys()),GRB.EQUAL,1,name = 'budget')
Constr['returns'] = psp.addConstr(quicksum(X[i]*R[i] for i in X.keys()),'>=',expected_returns, name = 'returns')

Constr['us'] = psp.addConstr(quicksum(X[i] for i in range(hk)),'<=',prop_country,name = 'us')
Constr['hk'] = psp.addConstr(quicksum(X[i] for i in range(hk,uk)),'<=',prop_country,name = 'hk')
Constr['uk'] = psp.addConstr(quicksum(X[i] for i in range(uk,end)),'<=',prop_country,name = 'uk')

for row in type_tuple:
    Constr[row[0]] = psp.addConstr(quicksum(X[i] for i in indices[row[1]][0]),'<=',prop_industry,name=row[0])
    
# Limit on number of stocks
for i in range(len(R)):
    Constr[i] = psp.addConstr(X[i],'<=',Y[i],name='Stockinside'+str(i))

Constr['max_num_stocks'] = psp.addConstr(quicksum(j for i,j in Y.items()),'<=',N_max,name='max_num_stocks')
    
# ufl.setParam('TimeLimit', 900)
# ufl.setParam('DualReductions',0)

psp.modelSense = GRB.MINIMIZE
psp.update()

psp.optimize()
print('Runtime:',psp.Runtime)
psp.update()
# Out:
# Optimize a model with 64 rows, 106 columns and 371 nonzeros
# Model has 1431 quadratic objective terms
# Variable types: 53 continuous, 53 integer (53 binary)
# Coefficient statistics:
#   Matrix range     [7e-06, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-08, 5e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [8e-04, 6e+00]
# Found heuristic solution: objective 0.0001430
# Presolve time: 0.00s
# Presolved: 64 rows, 106 columns, 371 nonzeros
# Presolved model has 1431 quadratic objective terms
# Variable types: 53 continuous, 53 integer (53 binary)
#
# Root relaxation: objective 4.125235e-05, 93 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00004    0   16    0.00014    0.00004  71.1%     -    0s
# H    0     0                       0.0000760    0.00004  45.8%     -    0s
# ...

# %%
sum(j.X for i,j in Y.items())
# Out:
# 6.0

# %%
# Portfolio selection with country restriction, industry restriction and max no. of assets, and integral counts for country and industry
psp = Model('Portfolio')
X = {}
Y = {}
for i in range(len(R)):
    Y[i] = psp.addVar(vtype=GRB.BINARY,name='Stockinside'+str(i))
    X[i] = psp.addVar(ub=1.0,name='Stock'+str(i))

a = []
for i in range(len(R)):
    for j in range(len(R)):
        a.append((i,j))
        
#indices
us, hk, uk, end = 0, 26, 38, len(X)

psp.setObjective(quicksum(C[i,j]*X[i]*X[j] for i,j in a))

Constr = {}

Constr['budget'] = psp.addConstr(quicksum(X[i] for i in X.keys()),GRB.EQUAL,1,name = 'budget')
Constr['returns'] = psp.addConstr(quicksum(X[i]*R[i] for i in X.keys()),'>=',expected_returns, name = 'returns')

Constr['us'] = psp.addConstr(quicksum(X[i] for i in range(hk)),'<=',prop_country,name = 'us')
Constr['hk'] = psp.addConstr(quicksum(X[i] for i in range(hk,uk)),'<=',prop_country,name = 'hk')
Constr['uk'] = psp.addConstr(quicksum(X[i] for i in range(uk,end)),'<=',prop_country,name = 'uk')
Constr['us'] = psp.addConstr(quicksum(Y[i] for i in range(hk)),'<=',N_country,name = 'us')
Constr['hk'] = psp.addConstr(quicksum(Y[i] for i in range(hk,uk)),'<=',N_country,name = 'hk')
Constr['uk'] = psp.addConstr(quicksum(Y[i] for i in range(uk,end)),'<=',N_country,name = 'uk')

for row in type_tuple:
    Constr[row[0]] = psp.addConstr(quicksum(X[i] for i in indices[row[1]][0]),'<=',prop_industry,name=row[0])
    Constr[row[0]] = psp.addConstr(quicksum(Y[i] for i in indices[row[1]][0]),'<=',N_industry,name=row[0])
    
# Limit on number of stocks
for i in range(len(R)):
    Constr[i] = psp.addConstr(X[i],'<=',Y[i],name='Stockinside'+str(i))

Constr['max_num_stocks'] = psp.addConstr(quicksum(j for i,j in Y.items()),'<=',N_max,name='max_num_stocks')
    
# ufl.setParam('TimeLimit', 900)
# ufl.setParam('DualReductions',0)

psp.modelSense = GRB.MINIMIZE
psp.update()

psp.optimize()
print('Runtime:',psp.Runtime)
psp.update()
# Out:
# Optimize a model with 72 rows, 106 columns and 477 nonzeros
# Model has 1431 quadratic objective terms
# Variable types: 53 continuous, 53 integer (53 binary)
# Coefficient statistics:
#   Matrix range     [7e-06, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [7e-08, 5e-03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [8e-04, 6e+00]
# Presolve time: 0.00s
# Presolved: 72 rows, 106 columns, 477 nonzeros
# Presolved model has 1431 quadratic objective terms
# Variable types: 53 continuous, 53 integer (53 binary)
#
# Root relaxation: objective 4.125235e-05, 93 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00004    0   16          -    0.00004      -     -    0s
# H    0     0                       0.0000665    0.00004  38.0%     -    0s
# ...

# %%
sum(j.X for i,j in Y.items())
# Out:
# 6.0
